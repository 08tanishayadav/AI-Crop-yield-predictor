# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pstore=pd.read_csv(r"C:\Users\Tanisha Yadav\Downloads\crop_yield-1.csv")

pstore.info
# Out:
# <bound method DataFrame.info of               Crop  Crop_Year       Season          State       Area  \
# 0        Arhar/Tur     1998.0  Kharif              Punjab     8700.0
# 1            Bajra     1998.0  Kharif              Punjab     4000.0
# 2           Barley     1998.0  Rabi                Punjab    31000.0
# 3     Cotton(lint)     1998.0  Kharif              Punjab   562000.0
# 4             Gram     1998.0  Rabi                Punjab    15200.0
# ...            ...        ...          ...            ...        ...
# 4420     Sunflower     2005.0  Summer       Uttar Pradesh    12599.0
# 4421  Sweet potato     2005.0  Whole Year   Uttar Pradesh    20476.0
# 4422       Tobacco     2005.0  Whole Year   Uttar Pradesh    20591.0
# 4423      Turmeric     2005.0  Rabi         Uttar Pradesh      979.0
# 4424         Wheat     2005.0  Rabi         Uttar Pradesh  9163949.0
#
#       Annual_Rainfall    Fertilizer   Pesticide      Yield
# ...

# %%
print(pstore.isnull().sum())
# Out:
# Crop               299
# Crop_Year          299
# Season             299
# State              299
# Area               299
# Annual_Rainfall    299
# Fertilizer         299
# Pesticide          299
# Yield              299
# dtype: int64

# %%
pstore=pstore.dropna()
print(pstore.isnull().sum())
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
pstore
# Out:
#               Crop  Crop_Year       Season          State       Area  \
# 0        Arhar/Tur     1998.0  Kharif              Punjab     8700.0
# 1            Bajra     1998.0  Kharif              Punjab     4000.0
# 2           Barley     1998.0  Rabi                Punjab    31000.0
# 3     Cotton(lint)     1998.0  Kharif              Punjab   562000.0
# 4             Gram     1998.0  Rabi                Punjab    15200.0
# ...            ...        ...          ...            ...        ...
# 4420     Sunflower     2005.0  Summer       Uttar Pradesh    12599.0
# 4421  Sweet potato     2005.0  Whole Year   Uttar Pradesh    20476.0
# 4422       Tobacco     2005.0  Whole Year   Uttar Pradesh    20591.0
# 4423      Turmeric     2005.0  Rabi         Uttar Pradesh      979.0
# 4424         Wheat     2005.0  Rabi         Uttar Pradesh  9163949.0
#
#       Annual_Rainfall    Fertilizer   Pesticide      Yield
# 0               588.6  8.595600e+05     2523.00   0.685000
# ...

# %%
#category_data = pstore.groupby('Crop')[['Area', 'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield']].mean().round(3)
#category_data

# %%
#pstore['Annual_Rainfall']=pd.to_numeric(pstore['Annual_Rainfall'], errors='coerce')
#pstore['Fertilizer']=pd.to_numeric(pstore['Fertilizer'], errors='coerce')
#pstore['Pesticide']=pd.to_numeric(pstore['Pesticide'], errors='coerce')
#pstore['Yield']=pd.to_numeric(pstore['Yield'], errors='coerce')
#pstore['Area']=pd.to_numeric(pstore['Area'], errors='coerce')

#pstore['Annual_Rainfall']=pd.to_numeric(pstore['Annual_Rainfall'], errors='coerce')
#pstore['Fertilizer']=pd.to_numeric(pstore['Fertilizer'], errors='coerce')
#pstore['Pesticide']=pd.to_numeric(pstore['Pesticide'], errors='coerce')
#pstore['Yield']=pd.to_numeric(pstore['Yield'], errors='coerce')
#pstore['Area']=pd.to_numeric(pstore['Area'], errors='coerce')

pstore.loc[:, 'Annual_Rainfall'] = pd.to_numeric(pstore['Annual_Rainfall'], errors='coerce')
pstore.loc[:, 'Fertilizer'] = pd.to_numeric(pstore['Fertilizer'], errors='coerce')
pstore.loc[:, 'Pesticide'] = pd.to_numeric(pstore['Pesticide'], errors='coerce')
pstore.loc[:, 'Yield'] = pd.to_numeric(pstore['Yield'], errors='coerce')
pstore.loc[:, 'Area'] = pd.to_numeric(pstore['Area'], errors='coerce')

#This parameter tells pandas how to handle values that cannot be converted to numeric types. When errors='coerce' is used, any values that cannot be converted (e.g., strings or other non-numeric values) will be replaced with NaN (Not a Number). This prevents errors that would otherwise occur if non-numeric values were encountered.

#Based on your code snippet, it looks like you're converting columns in your DataFrame pstore to numeric values using pd.to_numeric(), with errors coerced to NaN. If you're seeing the SettingWithCopyWarning, it suggests that you might be working with a view of the DataFrame, not a direct reference, and modifications might not be applied as expected.
#To avoid the warning and ensure you are modifying the DataFrame correctly, use the .loc[] accessor for assignment or verify that you are working with the DataFrame directly rather than a slice or view.


print(pstore)
# Out:
#               Crop  Crop_Year       Season          State       Area  \
# 0        Arhar/Tur     1998.0  Kharif              Punjab     8700.0
# 1            Bajra     1998.0  Kharif              Punjab     4000.0
# 2           Barley     1998.0  Rabi                Punjab    31000.0
# 3     Cotton(lint)     1998.0  Kharif              Punjab   562000.0
# 4             Gram     1998.0  Rabi                Punjab    15200.0
# ...            ...        ...          ...            ...        ...
# 4420     Sunflower     2005.0  Summer       Uttar Pradesh    12599.0
# 4421  Sweet potato     2005.0  Whole Year   Uttar Pradesh    20476.0
# 4422       Tobacco     2005.0  Whole Year   Uttar Pradesh    20591.0
# 4423      Turmeric     2005.0  Rabi         Uttar Pradesh      979.0
# 4424         Wheat     2005.0  Rabi         Uttar Pradesh  9163949.0
#
#       Annual_Rainfall    Fertilizer   Pesticide      Yield
# 0               588.6  8.595600e+05     2523.00   0.685000
# ...

# %%
category_data = pstore.groupby('Crop')[['Area', 'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield']].mean().round(3)
category_data
# Out:
#                               Area  Annual_Rainfall    Fertilizer   Pesticide  \
# Crop
# Arhar/Tur               119319.058          979.721  1.606687e+07   32797.088
# Bajra                   283514.391          933.611  3.779104e+07   75679.630
# Banana                   17733.044          869.243  2.617324e+06    5706.599
# Barley                   59530.439          956.954  7.753874e+06   15722.880
# Black pepper              8523.500         1032.300  8.449268e+05    2197.205
# Cardamom                 13152.291         1225.833  1.321728e+06    3421.695
# Cashewnut                    1.000          800.800  9.467000e+01       0.250
# Castor seed               2480.077         1060.368  3.033914e+05     669.939
# Coconut                  74819.429         1561.100  8.849563e+06   20561.355
# Coriander                53203.053          883.009  7.670928e+06   15572.802
# Cotton(lint)            294014.782          872.922  3.877141e+07   77376.080
# ...

# %%
coorelation=pstore[['Area', 'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield']].corr()
coorelation
# Out:
#                      Area  Annual_Rainfall  Fertilizer  Pesticide     Yield
# Area             1.000000        -0.107886    0.981725   0.963635 -0.013855
# Annual_Rainfall -0.107886         1.000000   -0.098225  -0.093113  0.070216
# Fertilizer       0.981725        -0.098225    1.000000   0.968172 -0.013481
# Pesticide        0.963635        -0.093113    0.968172   1.000000 -0.013049
# Yield           -0.013855         0.070216   -0.013481  -0.013049  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(5,4))
sns.heatmap(coorelation, annot=True, cmap='coolwarm')
plt.title("COORELATION HEATMAP")
plt.show()

# %%
import itertools
crops=['Arhar/Tur','Bajra','Banana','Barley','Black pepper','Cardamom','Cashewnut','Castor seed','Coconut','Coriander','Cotton(lint)','Cowpea(Lobia)','Dry chillies','Garlic','Ginger','Gram','Groundnut','Guar seed','Horse-gram','Jowar','Jute','Khesari','Linseed','Maize','Masoor','Mesta','Moong(Green Gram)','Moth','Niger seed','Onion','Other  Rabi pulses','Other Cereals','Other Kharif pulses','other oilseeds','Other Summer Pulses','Peas & beans (Pulses)','Potato','Ragi','Rapeseed &Mustard','Rice','Safflower','Sannhamp','Sesamum','Small millets','Soyabean','Sugarcane','Sunflower','Sweet potato','Tapioca','Tobacco','Turmeric','Urad','Wheat']
seasons=['Autumn','Kharif','Rabi','Summer','Whole Year','Winter']
states=['Assam','Haryana','Himachal Pradesh','Karnataka','Madhya Pradesh','Punjab','Uttar Pradesh','Uttarakhand','West Bengal']

product=list(itertools.product(crops, seasons, states))

df=pd.DataFrame(product, columns=['Crop','Season','State'])

print(df)
# Out:
#            Crop  Season             State
# 0     Arhar/Tur  Autumn             Assam
# 1     Arhar/Tur  Autumn           Haryana
# 2     Arhar/Tur  Autumn  Himachal Pradesh
# 3     Arhar/Tur  Autumn         Karnataka
# 4     Arhar/Tur  Autumn    Madhya Pradesh
# ...         ...     ...               ...
# 2857      Wheat  Winter    Madhya Pradesh
# 2858      Wheat  Winter            Punjab
# 2859      Wheat  Winter     Uttar Pradesh
# 2860      Wheat  Winter       Uttarakhand
# 2861      Wheat  Winter       West Bengal
#
# [2862 rows x 3 columns]

# %%
df_encoded=pd.get_dummies(df, columns=['Crop','Season','State'])
print(df_encoded)
# Out:
#       Crop_Arhar/Tur  Crop_Bajra  Crop_Banana  Crop_Barley  Crop_Black pepper  \
# 0               True       False        False        False              False
# 1               True       False        False        False              False
# 2               True       False        False        False              False
# 3               True       False        False        False              False
# 4               True       False        False        False              False
# ...              ...         ...          ...          ...                ...
# 2857           False       False        False        False              False
# 2858           False       False        False        False              False
# 2859           False       False        False        False              False
# 2860           False       False        False        False              False
# 2861           False       False        False        False              False
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

#x = df_encoded.drop('Yield', axis=1)
#y = df_encoded['Yield']

# Assuming df_encoded contains the one-hot encoded columns for 'crop', 'season', and 'state'
# And pstore is your original DataFrame containing the other columns and the 'yield' column

# Combine encoded columns with other feature columns
# pstore should include columns: 'area', 'fertiliser', 'pesticide', and 'yield'
# df_encoded should include one-hot encoded columns for 'crop', 'season', 'state'

# Ensure df_encoded has the same number of rows as pstore

assert len(df_encoded)==len(pstore)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 17
#       3 from sklearn.metrics import mean_absolute_error
#       5 #x = df_encoded.drop('Yield', axis=1)
#       6 #y = df_encoded['Yield']
#       7
#    (...)
#      14
#      15 # Ensure df_encoded has the same number of rows as pstore
# ---> 17 assert len(df_encoded)==len(pstore)
#
# AssertionError:

# %%
df_encoded.columns
# Out:
# Index(['Crop_Arhar/Tur', 'Crop_Bajra', 'Crop_Banana', 'Crop_Barley',
#        'Crop_Black pepper', 'Crop_Cardamom', 'Crop_Cashewnut',
#        'Crop_Castor seed', 'Crop_Coconut', 'Crop_Coriander',
#        'Crop_Cotton(lint)', 'Crop_Cowpea(Lobia)', 'Crop_Dry chillies',
#        'Crop_Garlic', 'Crop_Ginger', 'Crop_Gram', 'Crop_Groundnut',
#        'Crop_Guar seed', 'Crop_Horse-gram', 'Crop_Jowar', 'Crop_Jute',
#        'Crop_Khesari', 'Crop_Linseed', 'Crop_Maize', 'Crop_Masoor',
#        'Crop_Mesta', 'Crop_Moong(Green Gram)', 'Crop_Moth', 'Crop_Niger seed',
#        'Crop_Onion', 'Crop_Other  Rabi pulses', 'Crop_Other Cereals',
#        'Crop_Other Kharif pulses', 'Crop_Other Summer Pulses',
#        'Crop_Peas & beans (Pulses)', 'Crop_Potato', 'Crop_Ragi',
#        'Crop_Rapeseed &Mustard', 'Crop_Rice', 'Crop_Safflower',
#        'Crop_Sannhamp', 'Crop_Sesamum', 'Crop_Small millets', 'Crop_Soyabean',
#        'Crop_Sugarcane', 'Crop_Sunflower', 'Crop_Sweet potato', 'Crop_Tapioca',
# ...

# %%
df_encoded = df_encoded.reset_index(drop=True)
pstore = pstore.reset_index(drop=True)

assert len(df_encoded) == len(pstore), "row counts do not match"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 4
#       1 df_encoded = df_encoded.reset_index(drop=True)
#       2 pstore = pstore.reset_index(drop=True)
# ----> 4 assert len(df_encoded) == len(pstore), "row counts do not match"
#
# AssertionError: row counts do not match

# %%
print(f"df_encoded shape: {df_encoded.shape}")
print(f"pstore shape: {pstore.shape}")
# Out:
# df_encoded shape: (2862, 68)
# pstore shape: (4126, 9)

# %%
pstore = pstore.dropna()

df_encoded = pd.get_dummies(pstore[['Crop','Season','State']])

# %%
pstore = pstore[['Crop','Season','State','Area','Annual_Rainfall','Fertilizer','Pesticide','Yield']]
df_encoded = pd.get_dummies(pstore[['Crop','Season','State']])

# %%
X_features = pstore[['Area','Annual_Rainfall','Fertilizer','Pesticide']]
x = pd.concat([df_encoded, X_features], axis=1)

y = pstore['Yield']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)


model = RandomForestRegressor()
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)

mae = mean_absolute_error(Y_test, y_pred)
print(f"mean absolute error: {mae:.3f}")
# Out:
# mean absolute error: 13.498

# %%
from sklearn.model_selection import StratifiedKFold

# Define cross-validation strategy
#cv = StratifiedKFold(n_splits=5)
# = RandomizedSearchCV(estimator=RandomForestRegressor(), param_distributions=param_dist, n_iter=10, cv=cv, scoring='r2', random_state=42)
#random_search.fit(X_train, Y_train)

from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer, r2_score

# Define parameter distribution
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# Define cross-validation strategy
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# Define custom scoring function
scoring = make_scorer(r2_score)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(),
    param_distributions=param_dist,
    n_iter=10,
    cv=cv,
    scoring=scoring,
    random_state=42
)

# Fit the model
random_search.fit(X_train, Y_train)

# Best parameters and model
print("Best Parameters:", random_search.best_params_)
best_model = random_search.best_estimator_

# Evaluate the best model
y_pred = best_model.predict(X_test)
mae = mean_absolute_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

print(f"Optimized Mean Absolute Error: {mae:.2f}")
print(f"Optimized R² Score: {r2:.2f}")

# Cross-validated R² scores
cv_scores = cross_val_score(best_model, x, y, cv=cv, scoring='r2')
print(f"Cross-Validated R² Scores: {cv_scores}")
print(f"Mean Cross-Validated R² Score: {cv_scores.mean():.2f}")
# Out:
# Best Parameters: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 30}
# Optimized Mean Absolute Error: 13.55
# Optimized R² Score: 0.76
# Cross-Validated R² Scores: [0.65218969 0.99993482 0.9995768  0.99997138 0.9984847 ]
# Mean Cross-Validated R² Score: 0.93

# %%
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
results = pd.DataFrame(random_search.cv_results_)

# Plotting the effect of different hyperparameters on performance
# Example: Visualize the effect of 'n_estimators' and 'max_depth' on mean test score

# Plot mean test score vs. 'n_estimators'
plt.figure(figsize=(12, 6))
sns.lineplot(data=results, x='param_n_estimators', y='mean_test_score', hue='param_max_depth', marker='o')
plt.title('Mean Test Score vs. Number of Estimators')
plt.xlabel('Number of Estimators')
plt.ylabel('Mean Test Score (R^2)')
plt.legend(title='Max Depth')
plt.grid(True)
plt.show()

# Plot mean test score vs. 'max_depth'
plt.figure(figsize=(12, 6))
sns.lineplot(data=results, x='param_max_depth', y='mean_test_score', hue='param_n_estimators', marker='o')
plt.title('Mean Test Score vs. Max Depth')
plt.xlabel('Max Depth')
plt.ylabel('Mean Test Score (R^2)')
plt.legend(title='Number of Estimators')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Tanisha Yadav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Tanisha Yadav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Tanisha Yadav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
